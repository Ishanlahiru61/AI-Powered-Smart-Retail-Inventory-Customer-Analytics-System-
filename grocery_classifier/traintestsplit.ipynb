# %%
import os
import random
import shutil


BASE_DIR = "/Users/ishanlahiru/Documents/grocery_classifier/dataset"  


classes = ["jelly", "nestamolt", "pelwatte", "rice_araliya", "rice_sathosa"]


TRAIN_RATIO = 0.7
VAL_RATIO = 0.15
TEST_RATIO = 0.15


IMAGE_EXTENSIONS = (".jpg", ".jpeg", ".png", ".heic")


for split in ["train", "validation", "test"]:
    split_path = os.path.join(BASE_DIR, split)
    os.makedirs(split_path, exist_ok=True)
    
    for cls in classes:
        os.makedirs(os.path.join(split_path, cls), exist_ok=True)

print(" Split folders created.")


for cls in classes:
    cls_path = os.path.join(BASE_DIR, cls)
    if not os.path.exists(cls_path):
        print(f"⚠️ Class folder {cls} not found, skipping...")
        continue

    
    images = [f for f in os.listdir(cls_path) if f.lower().endswith(IMAGE_EXTENSIONS)]
    random.shuffle(images)

    total = len(images)
    train_end = int(total * TRAIN_RATIO)
    val_end = train_end + int(total * VAL_RATIO)

    train_imgs = images[:train_end]
    val_imgs = images[train_end:val_end]
    test_imgs = images[val_end:]

    
    for img in train_imgs:
        shutil.move(os.path.join(cls_path, img), os.path.join(BASE_DIR, "train", cls, img))
    for img in val_imgs:
        shutil.move(os.path.join(cls_path, img), os.path.join(BASE_DIR, "validation", cls, img))
    for img in test_imgs:
        shutil.move(os.path.join(cls_path, img), os.path.join(BASE_DIR, "test", cls, img))

    print(f"{cls}: {len(train_imgs)} train, {len(val_imgs)} val, {len(test_imgs)} test")


for cls in classes:
    cls_path = os.path.join(BASE_DIR, cls)
    if os.path.exists(cls_path) and len(os.listdir(cls_path)) == 0:
        os.rmdir(cls_path)

print(" Dataset split completed successfully.")
# Out:
# ✅ Split folders created.
# ⚠️ Class folder jelly not found, skipping...
# ⚠️ Class folder nestamolt not found, skipping...
# ⚠️ Class folder pelwatte not found, skipping...
# ⚠️ Class folder rice_araliya not found, skipping...
# ⚠️ Class folder rice_sathosa not found, skipping...
# ✅ Dataset split completed successfully.

# %%
import numpy as np
from tensorflow.keras.models import load_model
from PIL import Image


MODEL_PATH = "/Users/ishanlahiru/Documents/grocery_application/grocery_classifier/dataset/best_grocery_model.h5"
IMG_SIZE = (224, 224)
CLASS_NAMES = ["jelly", "nestamolt", "pelwatte", "rice_araliya", "rice_sathosa"]
IMAGE_PATH = "/Users/ishanlahiru/Documents/grocery_application/grocery_classifier/dataset/new6.jpg"



model = load_model(MODEL_PATH)
print(" Model loaded.")


img = Image.open(IMAGE_PATH).convert("RGB")
img = img.resize(IMG_SIZE)
img_array = np.array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)


preds = model.predict(img_array)
class_idx = np.argmax(preds)
class_name = CLASS_NAMES[class_idx]
confidence = preds[0][class_idx]


print(f"Prediction for {IMAGE_PATH}: {class_name} ({confidence*100:.2f}% confidence)")
print("All class probabilities:")
for i, name in enumerate(CLASS_NAMES):
    print(f"{name}: {preds[0][i]*100:.2f}%")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#
: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947319952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947320144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947320336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947317840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947321488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947320912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947321104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947321296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947318800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947322448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947321872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947322064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947322256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947319760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947323408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947322832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947323024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947323216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947320720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947324368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947323792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947321680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947324560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947323984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947324752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947324176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947669072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947669456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947322640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947323600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947669264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947670224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947670032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947669648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947671376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947670800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947670992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947671184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947670416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947672336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947671760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947671952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947672144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947669840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947673296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947672720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947672912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947673104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947670608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947674256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947673680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947673872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947674064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947671568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947675216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947674640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947674832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947675024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947672528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947676176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947675600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947675792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947675984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947673488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947677136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947676560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947676752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947676944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947674448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947678096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947677520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947677712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947677904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947675408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947679056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947678480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947678672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947678864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947676368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947680016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947679440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947679632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947679824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947677328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947680976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947680400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947680592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947680784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947678288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947681936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947681360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947681552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947681744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947679248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947682896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947682320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947682512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947682704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947680208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947683856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947683280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947681168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947684624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12947684048: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ Model converted to TFLite
# W0000 00:00:1770307220.504339  524240 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1770307220.504353  524240 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# 2026-02-05 21:30:20.504624: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /var/folders/d5/p58vb38175d8xw9s73_rl4g00000gn/T/tmpzzli8izq
# 2026-02-05 21:30:20.510718: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2026-02-05 21:30:20.510726: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /var/folders/d5/p58vb38175d8xw9s73_rl4g00000gn/T/tmpzzli8izq
# 2026-02-05 21:30:20.586007: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2026-02-05 21:30:21.001468: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /var/folders/d5/p58vb38175d8xw9s73_rl4g00000gn/T/tmpzzli8izq
# 2026-02-05 21:30:21.125731: I tensorflow/cc/saved_model/loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 621107 microseconds.

# %%
import numpy as np
import tensorflow as tf
from PIL import Image


TFLITE_MODEL_PATH = "/Users/ishanlahiru/Documents/grocery_application/grocery_classifier/grocery_model.tflite"
IMAGE_PATH = "/Users/ishanlahiru/Documents/grocery_application/grocery_classifier/dataset/new6.jpg"

CLASS_NAMES = ["jelly", "nestamolt", "pelwatte", "rice_araliya", "rice_sathosa"]


interpreter = tf.lite.Interpreter(model_path=TFLITE_MODEL_PATH)
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()


img = Image.open(IMAGE_PATH).convert("RGB")
img = img.resize((224, 224))
img_array = np.array(img, dtype=np.float32) / 255.0
img_array = np.expand_dims(img_array, axis=0)


interpreter.set_tensor(input_details[0]["index"], img_array)


interpreter.invoke()


output = interpreter.get_tensor(output_details[0]["index"])
idx = np.argmax(output)

print(" TFLITE MODEL RESULT")
print("Predicted:", CLASS_NAMES[idx])
print("Confidence:", output[0][idx])
print("All:", output)
# Out:
#  TFLITE MODEL RESULT
# Predicted: rice_sathosa
# Confidence: 0.96244556
# All: [[7.7242497e-04 8.3955680e-04 2.4694826e-02 1.1247697e-02 9.6244556e-01]]
# /Users/ishanlahiru/Library/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
